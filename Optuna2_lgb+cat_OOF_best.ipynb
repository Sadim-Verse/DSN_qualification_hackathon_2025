# %%
 from google.colab import drive
# Mount Google Drive to access files stored there
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Data preprocessing modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import KFold, RandomizedSearchCV

# Algorithms for model training & testing
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
# !pip install lightgbm
from lightgbm import LGBMRegressor
import lightgbm as lgb
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lightgbm) (1.16.1)

# %%
# Import data:
train_data = pd.read_csv("/content/drive/MyDrive/Colab_notebooks/train.csv")
test_data_n = pd.read_csv("/content/drive/MyDrive/Colab_notebooks/test.csv")

# %% [markdown]
# ## **Data Preprocessing**

# %%
train_data = train_data.drop(["id"], axis=1)
test_data = test_data_n.drop(["id"], axis=1)

# %%
display(train_data.head())
display(test_data.head())
# Out:
#            brand              model  model_year  milage      fuel_type  \
# 0           MINI      Cooper S Base        2007  213000       Gasoline
# 1        Lincoln              LS V8        2002  143250       Gasoline
# 2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# 3  Transmission w/Dual Shift Mode   Black   Black
# 4                     7-Speed A/T   Black   Beige
#
#                                  accident clean_title  price
# 0                           None reported         Yes   4200
# 1  At least 1 accident or damage reported         Yes   4999
# 2                           None reported         Yes  13900
# 3                           None reported         Yes  45000
# 4                           None reported         Yes  97500
#   brand                 model  model_year  milage fuel_type  \
# 0  Land        Rover LR2 Base        2015   98000  Gasoline
# 1  Land     Rover Defender SE        2020    9142    Hybrid
# 2  Ford    Expedition Limited        2022   28121  Gasoline
# 3  Audi         A6 2.0T Sport        2016   61258  Gasoline
# 4  Audi  A6 2.0T Premium Plus        2018   59000  Gasoline
#
#                                               engine        transmission  \
# 0       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 1  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 2                    3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 3                                     2.0 Liter TFSI           Automatic
# 4       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel                 A/T
#
#            ext_col int_col       accident clean_title
# 0            White   Beige  None reported         Yes
# 1           Silver   Black  None reported         Yes
# 2            White   Ebony  None reported         NaN
# 3  Silician Yellow   Black  None reported         NaN
# 4             Gray   Black  None reported         Yes

# %%
display(train_data.info())
display(test_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   brand         188533 non-null  object
#  1   model         188533 non-null  object
#  2   model_year    188533 non-null  int64
#  3   milage        188533 non-null  int64
#  4   fuel_type     183450 non-null  object
#  5   engine        188533 non-null  object
#  6   transmission  188533 non-null  object
#  7   ext_col       188533 non-null  object
#  8   int_col       188533 non-null  object
#  9   accident      186081 non-null  object
#  10  clean_title   167114 non-null  object
#  11  price         188533 non-null  int64
# dtypes: int64(3), object(9)
# memory usage: 17.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   brand         125690 non-null  object
#  1   model         125690 non-null  object
#  2   model_year    125690 non-null  int64
#  3   milage        125690 non-null  int64
#  4   fuel_type     122307 non-null  object
#  5   engine        125690 non-null  object
#  6   transmission  125690 non-null  object
#  7   ext_col       125690 non-null  object
#  8   int_col       125690 non-null  object
#  9   accident      124058 non-null  object
#  10  clean_title   111451 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 10.5+ MB
# None

# %%
# get the missing values in the train and test data
null_train = train_data.isnull().sum()
null_test = test_data.isnull().sum()

display(null_train[null_train > 0])
display(null_test[null_test > 0])
# Out:
# fuel_type       5083
# accident        2452
# clean_title    21419
# dtype: int64
# fuel_type       3383
# accident        1632
# clean_title    14239
# dtype: int64

# %%
display(train_data['fuel_type'].unique())
display(test_data['fuel_type'].unique())

display(train_data['accident'].unique())
display(test_data['accident'].unique())

display(train_data['clean_title'].unique())
display(test_data['clean_title'].unique())
# Out:
# array(['Gasoline', 'E85 Flex Fuel', nan, 'Hybrid', 'Diesel',
#        'Plug-In Hybrid', '–', 'not supported'], dtype=object)
# array(['Gasoline', 'Hybrid', 'Diesel', 'E85 Flex Fuel', nan,
#        'Plug-In Hybrid', '–', 'not supported'], dtype=object)
# array(['None reported', 'At least 1 accident or damage reported', nan],
#       dtype=object)
# array(['None reported', 'At least 1 accident or damage reported', nan],
#       dtype=object)
# array(['Yes', nan], dtype=object)
# array(['Yes', nan], dtype=object)

# %%
# fill 'fuel_type' null values with 'unknown'
train_data['fuel_type'] = train_data['fuel_type'].fillna('Unknown')
test_data['fuel_type'] = test_data['fuel_type'].fillna('Unknown')

# fill 'accident' null values with 'unknown'
train_data['accident'] = train_data['accident'].fillna('Unknown')
test_data['accident'] = test_data['accident'].fillna('Unknown')

# fill 'clean_title' null values with 'No'
train_data['clean_title'] = train_data['clean_title'].fillna('No')
test_data['clean_title'] = test_data['clean_title'].fillna('No')

# %% [markdown]
# Helper functions to reduce the amount of unique values in their specific column

# %%
# engine: 'Gasoline', 'E85 Flex Fuel', 'Hybrid', 'Diesel','Plug-In Hybrid'
def engine_fuel(engine):
    if 'Gasoline' in engine:
        return 'Gasoline'
    elif 'E85 Flex Fuel' in engine: return 'E85 Flex Fuel'
    elif 'Hybrid' in engine: return 'Hybrid'
    elif 'Diesel' in engine: return 'Diesel'
    elif 'Plug-In Hybrid' in engine: return 'Plug-In Hybrid'
    else:
        return 'None'

# transmission: Manual, Automatic, Continuously Variable, Dual-Clutch,...
def transmission_type(transmission):
    t = transmission.lower()

    if 'a/t' in t or 'automatic' in t or 'at' in t:
        return 'Automatic'
    elif 'm/t' in t or 'manual' in t or 'mt' in t: return 'Manual'
    elif 'cvt' in t: return 'CVT'
    elif 'dct' in t: return 'DCT'
    elif 'fixed gear' in t: return 'Fixed Gear'
    elif 'variable' in t: return 'Variable'
    elif 'single-speed' in t or '1-speed' in t: return 'Single-speed'
    else:
        return 'Other'

# %%
# apply the helper functions to the train and test data
train_data['engine_new'] = train_data['engine'].apply(engine_fuel)
test_data['engine_new'] = test_data['engine'].apply(engine_fuel)

train_data['transmission'] = train_data['transmission'].apply(transmission_type)
test_data['transmission'] = test_data['transmission'].apply(transmission_type)

# %% [markdown]
# lightgbm will use the ordinal encoded data and catboost will not use any encoding for its data

# %%
# get the values of X and y
X_lgbm = train_data.drop(columns=['price'], axis=1)
X_cat = train_data.drop(columns=['price'], axis=1)
y = train_data['price']

test_data_lgbm = test_data.copy()
test_data_cat = test_data.copy()

# %%
X_lgbm
# Out:
#                 brand                     model  model_year  milage  \
# 0                MINI             Cooper S Base        2007  213000
# 1             Lincoln                     LS V8        2002  143250
# 2           Chevrolet         Silverado 2500 LT        2002  136731
# 3             Genesis          G90 5.0 Ultimate        2017   19500
# 4       Mercedes-Benz               Metris Base        2021    7388
# ...               ...                       ...         ...     ...
# 188528       Cadillac     Escalade ESV Platinum        2017   49000
# 188529  Mercedes-Benz  AMG C 43 AMG C 43 4MATIC        2018   28600
# 188530  Mercedes-Benz    AMG GLC 63 Base 4MATIC        2021   13650
# 188531           Audi          S5 3.0T Prestige        2022   13895
# 188532        Porsche                Macan Base        2016   59500
#
#             fuel_type                                             engine  \
# 0            Gasoline       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1            Gasoline       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2       E85 Flex Fuel  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3            Gasoline       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4            Gasoline       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...               ...                                                ...
# 188528       Gasoline       420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel
# 188529       Gasoline      385.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 188530       Gasoline       469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel
# 188531       Gasoline                                               3.0L
# 188532       Gasoline       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#        transmission                    ext_col int_col  \
# 0         Automatic                     Yellow    Gray
# 1         Automatic                     Silver   Beige
# 2         Automatic                       Blue    Gray
# 3             Other                      Black   Black
# 4         Automatic                      Black   Beige
# ...             ...                        ...     ...
# 188528        Other                      White   Beige
# 188529    Automatic                      White   Black
# 188530    Automatic                      White   Black
# 188531    Automatic  Daytona Gray Pearl Effect   Black
# 188532        Other                      White   Black
#
#                                       accident clean_title engine_new
# 0                                None reported         Yes   Gasoline
# 1       At least 1 accident or damage reported         Yes   Gasoline
# 2                                None reported         Yes       None
# 3                                None reported         Yes   Gasoline
# 4                                None reported         Yes   Gasoline
# ...                                        ...         ...        ...
# 188528                           None reported         Yes   Gasoline
# 188529  At least 1 accident or damage reported         Yes   Gasoline
# 188530                           None reported         Yes   Gasoline
# 188531                           None reported          No       None
# 188532                           None reported         Yes   Gasoline
#
# [188533 rows x 12 columns]

# %%
# get the names of the numerical columns and categorical columns in the data
num_cols = [col for col in train_data.columns if train_data[col].dtype in ['int64', 'float64']]
cat_cols = [col for col in train_data.columns if train_data[col].dtype in ['object']]

print("Num Cols: ", num_cols)
print("Cat Cols: ", cat_cols)
# Out:
# Num Cols:  ['model_year', 'milage', 'price']
# Cat Cols:  ['brand', 'model', 'fuel_type', 'engine', 'transmission', 'ext_col', 'int_col', 'accident', 'clean_title', 'engine_new']

# %%
# Ordinal Encode the features for X_lgbm:
oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

cat_enc_tr = oe.fit_transform(X_lgbm[cat_cols])
cat_enc_te = oe.transform(test_data_lgbm[cat_cols])

# %%
cat_enc_tr = pd.DataFrame(data=cat_enc_tr, columns=cat_cols)
X_lgbm[cat_cols] = cat_enc_tr

cat_enc_te = pd.DataFrame(data=cat_enc_te, columns=cat_cols)
test_data_lgbm[cat_cols] = cat_enc_te

# %%
display(X_lgbm.head())
display(test_data_lgbm.head())
# Out:
#    brand   model  model_year  milage  fuel_type  engine  transmission  \
# 0   31.0   495.0        2007  213000        2.0   116.0           0.0
# 1   28.0   930.0        2002  143250        2.0   366.0           0.0
# 2    9.0  1575.0        2002  136731        1.0   640.0           0.0
# 3   16.0   758.0        2017   19500        2.0   863.0           4.0
# 4   36.0  1077.0        2021    7388        2.0   259.0           0.0
#
#    ext_col  int_col  accident  clean_title  engine_new
# 0    312.0     71.0       1.0          1.0         1.0
# 1    263.0     10.0       0.0          1.0         1.0
# 2     38.0     71.0       1.0          1.0         3.0
# 3     29.0     14.0       1.0          1.0         1.0
# 4     29.0     10.0       1.0          1.0         1.0
#    brand   model  model_year  milage  fuel_type  engine  transmission  \
# 0   26.0  1390.0        2015   98000        2.0   325.0           0.0
# 1   26.0  1377.0        2020    9142        3.0   787.0           0.0
# 2   14.0   636.0        2022   28121        2.0   540.0           0.0
# 3    3.0   182.0        2016   61258        2.0   192.0           0.0
# 4    3.0   181.0        2018   59000        2.0   364.0           0.0
#
#    ext_col  int_col  accident  clean_title  engine_new
# 0    304.0     10.0       1.0          1.0         1.0
# 1    263.0     14.0       1.0          1.0         1.0
# 2    304.0     57.0       1.0          0.0         3.0
# 3    261.0     14.0       1.0          0.0         3.0
# 4    128.0     14.0       1.0          1.0         1.0

# %% [markdown]
# ## **Model Training & Evaluation**

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.16.5)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 7.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.9.0 optuna-4.5.0

# %%
import optuna

# Define Optuna objective functions
def objective_lgbm(trial):
    lgbm_params = {
        "objective": "regression",
        "metric": "rmse",
        "n_estimators": trial.suggest_int("n_estimators", 200, 2000),
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.2),
        "num_leaves": trial.suggest_int("num_leaves", 31, 511),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 200),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-6, 1.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-6, 1.0, log=True),
        "random_state": 42,
        "early_stopping_rounds": 200,
        "n_jobs": -1,
        "verbosity": -1,
        "boosting_type": trial.suggest_categorical("boosting_type", ["gbdt"]),
    }

    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    rmse_scores = []

    for fold, (tr_idx, val_idx) in enumerate(cv.split(X_lgbm, y)):
        X_tr, X_val = X_lgbm.iloc[tr_idx], X_lgbm.iloc[val_idx]
        y_tr, y_val = y.iloc[tr_idx], y.iloc[val_idx]

        model = LGBMRegressor(**lgbm_params)
        model.fit(X_tr, y_tr,
                  eval_set=[(X_val, y_val)],
                  eval_metric="rmse",)

        preds = model.predict(X_val)
        rmse = root_mean_squared_error(y_val, preds)
        rmse_scores.append(rmse)

    return np.mean(rmse_scores)


# LGBM Optuna study
print("Running Optuna study for LightGBM...")
pruner = optuna.pruners.SuccessiveHalvingPruner()
study_lgbm = optuna.create_study(direction="minimize", pruner=pruner)
study_lgbm.optimize(objective_lgbm, n_trials=150, timeout=60*90)

print("\nBest parameters for LightGBM:", study_lgbm.best_params)
print("Best RMSE for LightGBM:", study_lgbm.best_value)
best_lgb_params = study_lgbm.best_params
# Out:
# [I 2025-09-12 08:25:37,244] A new study created in memory with name: no-name-6b40a011-2d85-44b0-82f0-ed63829ee24c
# Running Optuna study for LightGBM...
# [I 2025-09-12 08:25:57,536] Trial 0 finished with value: 72748.21729833036 and parameters: {'n_estimators': 658, 'learning_rate': 0.13174083274815573, 'num_leaves': 44, 'max_depth': 12, 'min_child_samples': 26, 'subsample': 0.7140739459616219, 'colsample_bytree': 0.6080906796572331, 'reg_alpha': 0.0036180769256207073, 'reg_lambda': 0.0001340215661298201, 'boosting_type': 'gbdt'}. Best is trial 0 with value: 72748.21729833036.
# [I 2025-09-12 08:26:22,129] Trial 1 finished with value: 72709.68501749609 and parameters: {'n_estimators': 888, 'learning_rate': 0.1840440941253236, 'num_leaves': 280, 'max_depth': 10, 'min_child_samples': 182, 'subsample': 0.5798270113431705, 'colsample_bytree': 0.8443343698302974, 'reg_alpha': 0.037164339434207855, 'reg_lambda': 0.02689412433395196, 'boosting_type': 'gbdt'}. Best is trial 1 with value: 72709.68501749609.
# [I 2025-09-12 08:26:52,218] Trial 2 finished with value: 72935.02510930951 and parameters: {'n_estimators': 678, 'learning_rate': 0.0755219606803699, 'num_leaves': 346, 'max_depth': 10, 'min_child_samples': 17, 'subsample': 0.8362371102968413, 'colsample_bytree': 0.7346798957000602, 'reg_alpha': 0.02951896480280191, 'reg_lambda': 0.00011543945028036584, 'boosting_type': 'gbdt'}. Best is trial 1 with value: 72709.68501749609.
# [I 2025-09-12 08:29:24,595] Trial 3 finished with value: 72940.18446940163 and parameters: {'n_estimators': 1586, 'learning_rate': 0.0056801137430578285, 'num_leaves': 468, 'max_depth': 10, 'min_child_samples': 8, 'subsample': 0.7633626435530156, 'colsample_bytree': 0.6910546805068714, 'reg_alpha': 0.015041689364805181, 'reg_lambda': 0.05754469127203175, 'boosting_type': 'gbdt'}. Best is trial 1 with value: 72709.68501749609.
# [I 2025-09-12 08:29:43,529] Trial 4 finished with value: 72675.67742523566 and parameters: {'n_estimators': 1455, 'learning_rate': 0.17760155435992267, 'num_leaves': 121, 'max_depth': 7, 'min_child_samples': 179, 'subsample': 0.9426353040450244, 'colsample_bytree': 0.9381468664198559, 'reg_alpha': 0.00028993789375174523, 'reg_lambda': 2.0738728266976037e-06, 'boosting_type': 'gbdt'}. Best is trial 4 with value: 72675.67742523566.
# [I 2025-09-12 08:30:07,356] Trial 5 finished with value: 72634.06412092509 and parameters: {'n_estimators': 1143, 'learning_rate': 0.12377206529029737, 'num_leaves': 112, 'max_depth': 8, 'min_child_samples': 170, 'subsample': 0.5873476652809861, 'colsample_bytree': 0.8531775947729651, 'reg_alpha': 0.00039058823389086586, 'reg_lambda': 3.8088700060306916e-05, 'boosting_type': 'gbdt'}. Best is trial 5 with value: 72634.06412092509.
# [I 2025-09-12 08:30:35,985] Trial 6 finished with value: 72620.42468728672 and parameters: {'n_estimators': 656, 'learning_rate': 0.1272800817485651, 'num_leaves': 322, 'max_depth': 4, 'min_child_samples': 71, 'subsample': 0.584316972815598, 'colsample_bytree': 0.6064353150714037, 'reg_alpha': 0.0014702156924724763, 'reg_lambda': 0.010779995248548552, 'boosting_type': 'gbdt'}. Best is trial 6 with value: 72620.42468728672.
# [I 2025-09-12 08:30:51,336] Trial 7 finished with value: 73203.49408299002 and parameters: {'n_estimators': 1690, 'learning_rate': 0.1437526063243388, 'num_leaves': 71, 'max_depth': 12, 'min_child_samples': 5, 'subsample': 0.5384710541491726, 'colsample_bytree': 0.8640502520133309, 'reg_alpha': 2.8213065923583764e-05, 'reg_lambda': 4.524273103850896e-05, 'boosting_type': 'gbdt'}. Best is trial 6 with value: 72620.42468728672.
# [I 2025-09-12 08:32:05,334] Trial 8 finished with value: 72584.25925736703 and parameters: {'n_estimators': 386, 'learning_rate': 0.01230823413579878, 'num_leaves': 196, 'max_depth': 9, 'min_child_samples': 35, 'subsample': 0.7908902703404854, 'colsample_bytree': 0.4718393833738669, 'reg_alpha': 0.30758769117982926, 'reg_lambda': 8.654948618203073e-06, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 72584.25925736703.
# [I 2025-09-12 08:32:23,993] Trial 9 finished with value: 72680.31266298775 and parameters: {'n_estimators': 496, 'learning_rate': 0.19093533988219036, 'num_leaves': 449, 'max_depth': 3, 'min_child_samples': 65, 'subsample': 0.7546289739037956, 'colsample_bytree': 0.8915716186395015, 'reg_alpha': 0.043965280459797106, 'reg_lambda': 0.0007930494976481633, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 72584.25925736703.
# [I 2025-09-12 08:32:53,823] Trial 10 finished with value: 72690.01005369844 and parameters: {'n_estimators': 228, 'learning_rate': 0.015541599290701577, 'num_leaves': 188, 'max_depth': 7, 'min_child_samples': 125, 'subsample': 0.9645385598811556, 'colsample_bytree': 0.40417130793040656, 'reg_alpha': 0.7726847201066475, 'reg_lambda': 0.769624259730541, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 72584.25925736703.
# [I 2025-09-12 08:33:13,882] Trial 11 finished with value: 72795.8094086484 and parameters: {'n_estimators': 225, 'learning_rate': 0.0607451585269034, 'num_leaves': 241, 'max_depth': 3, 'min_child_samples': 68, 'subsample': 0.6685183734854581, 'colsample_bytree': 0.47099848130979965, 'reg_alpha': 1.0250174589388635e-06, 'reg_lambda': 1.9480976666421626e-06, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 72584.25925736703.
# [I 2025-09-12 08:33:42,092] Trial 12 finished with value: 72632.6685164702 and parameters: {'n_estimators': 1113, 'learning_rate': 0.08203905236022367, 'num_leaves': 352, 'max_depth': 6, 'min_child_samples': 66, 'subsample': 0.8529200081357007, 'colsample_bytree': 0.5485762326277498, 'reg_alpha': 0.9262437886990733, 'reg_lambda': 0.008833711936549965, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 72584.25925736703.
# [I 2025-09-12 08:34:23,169] Trial 13 finished with value: 72597.57336141728 and parameters: {'n_estimators': 556, 'learning_rate': 0.03975110661939022, 'num_leaves': 350, 'max_depth': 5, 'min_child_samples': 98, 'subsample': 0.661716563309412, 'colsample_bytree': 0.5491912952159299, 'reg_alpha': 2.4251063523671527e-05, 'reg_lambda': 0.0036741207828735324, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 72584.25925736703.
# [I 2025-09-12 08:34:58,112] Trial 14 finished with value: 72586.32742351203 and parameters: {'n_estimators': 368, 'learning_rate': 0.03887946373413856, 'num_leaves': 407, 'max_depth': 5, 'min_child_samples': 112, 'subsample': 0.6668651284748871, 'colsample_bytree': 0.5041933326780459, 'reg_alpha': 3.1866995950921638e-06, 'reg_lambda': 0.0012583112517422024, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 72584.25925736703.
# [I 2025-09-12 08:35:36,516] Trial 15 finished with value: 72534.57256281938 and parameters: {'n_estimators': 1988, 'learning_rate': 0.04388992644591841, 'num_leaves': 201, 'max_depth': 8, 'min_child_samples': 133, 'subsample': 0.813780013085506, 'colsample_bytree': 0.42384908116313785, 'reg_alpha': 1.6955808959339158e-06, 'reg_lambda': 1.0644210754427341e-05, 'boosting_type': 'gbdt'}. Best is trial 15 with value: 72534.57256281938.
# [I 2025-09-12 08:36:24,905] Trial 16 finished with value: 72553.53916077009 and parameters: {'n_estimators': 1962, 'learning_rate': 0.03674290548902086, 'num_leaves': 191, 'max_depth': 9, 'min_child_samples': 151, 'subsample': 0.8400540498819263, 'colsample_bytree': 0.4041785735841584, 'reg_alpha': 4.0941237323270356e-05, 'reg_lambda': 8.315608336182897e-06, 'boosting_type': 'gbdt'}. Best is trial 15 with value: 72534.57256281938.
# [I 2025-09-12 08:37:05,617] Trial 17 finished with value: 72585.63798633454 and parameters: {'n_estimators': 1972, 'learning_rate': 0.036958230707404935, 'num_leaves': 178, 'max_depth': 8, 'min_child_samples': 147, 'subsample': 0.8929322056158517, 'colsample_bytree': 0.7227029361579476, 'reg_alpha': 2.725351110668312e-05, 'reg_lambda': 9.664464615878029e-06, 'boosting_type': 'gbdt'}. Best is trial 15 with value: 72534.57256281938.
# [I 2025-09-12 08:37:38,420] Trial 18 finished with value: 72542.45144429182 and parameters: {'n_estimators': 1987, 'learning_rate': 0.06059423800157955, 'num_leaves': 249, 'max_depth': 9, 'min_child_samples': 150, 'subsample': 0.9023802469585583, 'colsample_bytree': 0.4108550640700252, 'reg_alpha': 5.109368452161124e-06, 'reg_lambda': 1.0502109625968335e-06, 'boosting_type': 'gbdt'}. Best is trial 15 with value: 72534.57256281938.
# [I 2025-09-12 08:38:09,449] Trial 19 finished with value: 72658.35106612797 and parameters: {'n_estimators': 1742, 'learning_rate': 0.09971415383439872, 'num_leaves': 249, 'max_depth': 11, 'min_child_samples': 197, 'subsample': 0.9126881669829269, 'colsample_bytree': 0.6479941239139294, 'reg_alpha': 3.269664463817874e-06, 'reg_lambda': 1.4219432272033803e-06, 'boosting_type': 'gbdt'}. Best is trial 15 with value: 72534.57256281938.
# [I 2025-09-12 08:38:40,333] Trial 20 finished with value: 72601.12695609368 and parameters: {'n_estimators': 1328, 'learning_rate': 0.0628380171316911, 'num_leaves': 291, 'max_depth': 9, 'min_child_samples': 138, 'subsample': 0.9948973170331407, 'colsample_bytree': 0.7804885620397608, 'reg_alpha': 1.1995042844085795e-06, 'reg_lambda': 0.0002880348918974125, 'boosting_type': 'gbdt'}. Best is trial 15 with value: 72534.57256281938.
# [I 2025-09-12 08:39:14,026] Trial 21 finished with value: 72543.63398077483 and parameters: {'n_estimators': 1974, 'learning_rate': 0.05342846474474211, 'num_leaves': 143, 'max_depth': 9, 'min_child_samples': 156, 'subsample': 0.827064423211748, 'colsample_bytree': 0.4061043585275835, 'reg_alpha': 6.367732851668227e-06, 'reg_lambda': 7.878633609892316e-06, 'boosting_type': 'gbdt'}. Best is trial 15 with value: 72534.57256281938.
# [I 2025-09-12 08:39:51,139] Trial 22 finished with value: 72549.7190896374 and parameters: {'n_estimators': 1829, 'learning_rate': 0.05863125060212573, 'num_leaves': 140, 'max_depth': 8, 'min_child_samples': 166, 'subsample': 0.8031818973305648, 'colsample_bytree': 0.43648670861326433, 'reg_alpha': 7.065670396679591e-06, 'reg_lambda': 5.538580815824333e-06, 'boosting_type': 'gbdt'}. Best is trial 15 with value: 72534.57256281938.
# [I 2025-09-12 08:40:19,094] Trial 23 finished with value: 72584.71216786743 and parameters: {'n_estimators': 1828, 'learning_rate': 0.09643582492571008, 'num_leaves': 230, 'max_depth': 7, 'min_child_samples': 128, 'subsample': 0.8923811481979984, 'colsample_bytree': 0.5332598136682288, 'reg_alpha': 0.00010969396470979623, 'reg_lambda': 2.6409483509663623e-05, 'boosting_type': 'gbdt'}. Best is trial 15 with value: 72534.57256281938.
# [I 2025-09-12 08:40:56,787] Trial 24 finished with value: 72599.84681004219 and parameters: {'n_estimators': 1581, 'learning_rate': 0.08086854246538319, 'num_leaves': 147, 'max_depth': 11, 'min_child_samples': 102, 'subsample': 0.8663619179231843, 'colsample_bytree': 0.4763000780469092, 'reg_alpha': 7.864254810091627e-06, 'reg_lambda': 4.105936392203939e-06, 'boosting_type': 'gbdt'}. Best is trial 15 with value: 72534.57256281938.
# [I 2025-09-12 08:41:32,078] Trial 25 finished with value: 72527.33246460892 and parameters: {'n_estimators': 1995, 'learning_rate': 0.05101421798433064, 'num_leaves': 98, 'max_depth': 9, 'min_child_samples': 155, 'subsample': 0.795214556350197, 'colsample_bytree': 0.437798275994333, 'reg_alpha': 7.733789387891466e-06, 'reg_lambda': 1.2064000395683555e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:42:50,585] Trial 26 finished with value: 72563.33661054543 and parameters: {'n_estimators': 1350, 'learning_rate': 0.01813131754800984, 'num_leaves': 72, 'max_depth': 6, 'min_child_samples': 126, 'subsample': 0.7264922674258105, 'colsample_bytree': 0.45636036692069537, 'reg_alpha': 0.00011655779129173719, 'reg_lambda': 1.0696478351883353e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:43:45,702] Trial 27 finished with value: 72578.3515726306 and parameters: {'n_estimators': 1846, 'learning_rate': 0.026692434604317687, 'num_leaves': 89, 'max_depth': 11, 'min_child_samples': 194, 'subsample': 0.7850035518772858, 'colsample_bytree': 0.59193553795774, 'reg_alpha': 2.355953430392895e-06, 'reg_lambda': 1.0199749048872304e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:44:21,518] Trial 28 finished with value: 72586.65275142917 and parameters: {'n_estimators': 1654, 'learning_rate': 0.06951939680931318, 'num_leaves': 224, 'max_depth': 8, 'min_child_samples': 90, 'subsample': 0.9330904820904903, 'colsample_bytree': 0.5113370342368647, 'reg_alpha': 1.3512231757782926e-05, 'reg_lambda': 1.7349154093461352e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:44:54,747] Trial 29 finished with value: 72595.91251959826 and parameters: {'n_estimators': 1846, 'learning_rate': 0.04662105796072091, 'num_leaves': 34, 'max_depth': 10, 'min_child_samples': 142, 'subsample': 0.7272707326525889, 'colsample_bytree': 0.5665190402095867, 'reg_alpha': 7.506016615873178e-05, 'reg_lambda': 0.00011288888968001116, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:45:30,964] Trial 30 finished with value: 72581.69323659032 and parameters: {'n_estimators': 1486, 'learning_rate': 0.08986402698346252, 'num_leaves': 506, 'max_depth': 6, 'min_child_samples': 163, 'subsample': 0.8760858682681194, 'colsample_bytree': 0.43856611647973454, 'reg_alpha': 0.005340894032134031, 'reg_lambda': 2.9972243948572855e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:46:03,210] Trial 31 finished with value: 72550.74430480921 and parameters: {'n_estimators': 1975, 'learning_rate': 0.056624057130217974, 'num_leaves': 158, 'max_depth': 9, 'min_child_samples': 158, 'subsample': 0.8146938715431896, 'colsample_bytree': 0.4202642685307744, 'reg_alpha': 7.123258285027006e-06, 'reg_lambda': 1.6444732156634992e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:46:35,769] Trial 32 finished with value: 72595.03488550633 and parameters: {'n_estimators': 1969, 'learning_rate': 0.11324136480393256, 'num_leaves': 291, 'max_depth': 9, 'min_child_samples': 180, 'subsample': 0.8135323334729821, 'colsample_bytree': 0.49773390568488085, 'reg_alpha': 2.3771213391093796e-06, 'reg_lambda': 4.1439243823873736e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:47:09,072] Trial 33 finished with value: 72541.51806647319 and parameters: {'n_estimators': 923, 'learning_rate': 0.04967972462158122, 'num_leaves': 94, 'max_depth': 10, 'min_child_samples': 132, 'subsample': 0.7733457977263649, 'colsample_bytree': 0.4431698903456465, 'reg_alpha': 1.2084192797113692e-05, 'reg_lambda': 6.73450344379854e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:47:55,600] Trial 34 finished with value: 72597.30499354008 and parameters: {'n_estimators': 888, 'learning_rate': 0.026950988075308827, 'num_leaves': 54, 'max_depth': 10, 'min_child_samples': 116, 'subsample': 0.6987465094149746, 'colsample_bytree': 0.6567704669240159, 'reg_alpha': 1.6954330348439268e-05, 'reg_lambda': 6.500383097192392e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:48:30,595] Trial 35 finished with value: 72549.09696406435 and parameters: {'n_estimators': 827, 'learning_rate': 0.04736391244317708, 'num_leaves': 99, 'max_depth': 11, 'min_child_samples': 135, 'subsample': 0.7671824576780824, 'colsample_bytree': 0.4477164580036456, 'reg_alpha': 1.103272837611236e-06, 'reg_lambda': 0.0004407018890364186, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:49:04,699] Trial 36 finished with value: 72721.48930529904 and parameters: {'n_estimators': 976, 'learning_rate': 0.0741760897960632, 'num_leaves': 268, 'max_depth': 10, 'min_child_samples': 114, 'subsample': 0.7012702072819046, 'colsample_bytree': 0.9951935001147694, 'reg_alpha': 0.0003716665027147595, 'reg_lambda': 0.00011187174198859021, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:49:52,443] Trial 37 finished with value: 72638.54280810468 and parameters: {'n_estimators': 1012, 'learning_rate': 0.02410182856735542, 'num_leaves': 119, 'max_depth': 12, 'min_child_samples': 86, 'subsample': 0.7740989307574658, 'colsample_bytree': 0.7687018171528004, 'reg_alpha': 4.387970708353672e-06, 'reg_lambda': 2.659776669113623e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:53:00,458] Trial 38 finished with value: 72554.94506098508 and parameters: {'n_estimators': 1259, 'learning_rate': 0.005646344901948805, 'num_leaves': 219, 'max_depth': 8, 'min_child_samples': 172, 'subsample': 0.7383263200943786, 'colsample_bytree': 0.5141901429832612, 'reg_alpha': 5.104998069366662e-05, 'reg_lambda': 1.909595818179796e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:53:28,446] Trial 39 finished with value: 72638.68311048306 and parameters: {'n_estimators': 1739, 'learning_rate': 0.16037096494660394, 'num_leaves': 315, 'max_depth': 10, 'min_child_samples': 145, 'subsample': 0.8374448949662475, 'colsample_bytree': 0.4798362547582632, 'reg_alpha': 0.0015652103486803754, 'reg_lambda': 6.145860328147541e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:53:57,649] Trial 40 finished with value: 72593.79924920526 and parameters: {'n_estimators': 1456, 'learning_rate': 0.11223596339058653, 'num_leaves': 168, 'max_depth': 7, 'min_child_samples': 187, 'subsample': 0.9220837055568875, 'colsample_bytree': 0.573665505421094, 'reg_alpha': 1.2140813773271558e-05, 'reg_lambda': 0.0002295693720536589, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:54:34,041] Trial 41 finished with value: 72541.00461179654 and parameters: {'n_estimators': 1896, 'learning_rate': 0.053773483177662604, 'num_leaves': 137, 'max_depth': 9, 'min_child_samples': 154, 'subsample': 0.8232941991896641, 'colsample_bytree': 0.4241156268001412, 'reg_alpha': 5.5946059013359476e-06, 'reg_lambda': 9.251613247202256e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:55:02,293] Trial 42 finished with value: 72547.68577299692 and parameters: {'n_estimators': 789, 'learning_rate': 0.07043780979236021, 'num_leaves': 119, 'max_depth': 8, 'min_child_samples': 131, 'subsample': 0.7964175162122418, 'colsample_bytree': 0.4377809756541603, 'reg_alpha': 2.0602083954048456e-06, 'reg_lambda': 3.101085857013291e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:55:37,327] Trial 43 finished with value: 72544.13072116121 and parameters: {'n_estimators': 1897, 'learning_rate': 0.04172113147382703, 'num_leaves': 81, 'max_depth': 9, 'min_child_samples': 152, 'subsample': 0.7513729583486445, 'colsample_bytree': 0.4297841220276714, 'reg_alpha': 1.2128869093010091e-05, 'reg_lambda': 3.1866794541955574e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:56:16,348] Trial 44 finished with value: 72558.58933988263 and parameters: {'n_estimators': 1757, 'learning_rate': 0.04978000620961202, 'num_leaves': 202, 'max_depth': 10, 'min_child_samples': 174, 'subsample': 0.8709691533771365, 'colsample_bytree': 0.4017404766400643, 'reg_alpha': 0.0001961114539039006, 'reg_lambda': 1.8783574013189255e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:57:06,977] Trial 45 finished with value: 72571.19001302033 and parameters: {'n_estimators': 1608, 'learning_rate': 0.030475044086428288, 'num_leaves': 58, 'max_depth': 9, 'min_child_samples': 121, 'subsample': 0.6196628356550096, 'colsample_bytree': 0.46494456544931545, 'reg_alpha': 4.448440562940978e-06, 'reg_lambda': 1.1415028118058017e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:57:37,228] Trial 46 finished with value: 72581.75474132704 and parameters: {'n_estimators': 1885, 'learning_rate': 0.08577444520125871, 'num_leaves': 134, 'max_depth': 10, 'min_child_samples': 162, 'subsample': 0.9481737372222242, 'colsample_bytree': 0.4830677553009326, 'reg_alpha': 0.0007892985889225004, 'reg_lambda': 0.18834326533061665, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:58:16,308] Trial 47 finished with value: 72565.43276875392 and parameters: {'n_estimators': 698, 'learning_rate': 0.0629401725124566, 'num_leaves': 262, 'max_depth': 8, 'min_child_samples': 138, 'subsample': 0.8502668419687122, 'colsample_bytree': 0.5290537985776987, 'reg_alpha': 2.0919174971001654e-05, 'reg_lambda': 5.756232019997348e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:58:43,742] Trial 48 finished with value: 72563.2307942904 and parameters: {'n_estimators': 1216, 'learning_rate': 0.06794289033483272, 'num_leaves': 110, 'max_depth': 7, 'min_child_samples': 149, 'subsample': 0.8971721390181346, 'colsample_bytree': 0.45269968679917033, 'reg_alpha': 1.5355496522627798e-06, 'reg_lambda': 4.8618912051732235e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 08:59:45,200] Trial 49 finished with value: 72589.58620918746 and parameters: {'n_estimators': 1768, 'learning_rate': 0.018282962275767665, 'num_leaves': 163, 'max_depth': 11, 'min_child_samples': 44, 'subsample': 0.9734355724052584, 'colsample_bytree': 0.42067602250830743, 'reg_alpha': 0.07805501849808519, 'reg_lambda': 1.2326802278906407e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:03:10,552] Trial 50 finished with value: 72869.10922829888 and parameters: {'n_estimators': 1040, 'learning_rate': 0.001904252223163025, 'num_leaves': 204, 'max_depth': 9, 'min_child_samples': 108, 'subsample': 0.8297633258982807, 'colsample_bytree': 0.6413365849901573, 'reg_alpha': 4.500825462154313e-05, 'reg_lambda': 2.091372109938693e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:03:43,169] Trial 51 finished with value: 72534.319013976 and parameters: {'n_estimators': 1981, 'learning_rate': 0.05461897251413191, 'num_leaves': 136, 'max_depth': 9, 'min_child_samples': 157, 'subsample': 0.8216630845313091, 'colsample_bytree': 0.40168980952990907, 'reg_alpha': 4.854298859152523e-06, 'reg_lambda': 5.494340974832513e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:04:23,834] Trial 52 finished with value: 72557.41595551737 and parameters: {'n_estimators': 1906, 'learning_rate': 0.05028460518908494, 'num_leaves': 95, 'max_depth': 8, 'min_child_samples': 167, 'subsample': 0.7810904558933154, 'colsample_bytree': 0.4931523095655631, 'reg_alpha': 4.280930667274131e-06, 'reg_lambda': 5.773877784303914e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:04:52,141] Trial 53 finished with value: 72561.83844724312 and parameters: {'n_estimators': 1997, 'learning_rate': 0.07846187641259679, 'num_leaves': 132, 'max_depth': 9, 'min_child_samples': 187, 'subsample': 0.5052871288967802, 'colsample_bytree': 0.42002214826783807, 'reg_alpha': 9.03147282397663e-06, 'reg_lambda': 1.2876165850227895e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:05:43,378] Trial 54 finished with value: 72557.18700022064 and parameters: {'n_estimators': 1904, 'learning_rate': 0.03357071468971532, 'num_leaves': 185, 'max_depth': 10, 'min_child_samples': 141, 'subsample': 0.8149774877202043, 'colsample_bytree': 0.4591989913676044, 'reg_alpha': 1.9369371630720464e-06, 'reg_lambda': 2.7674584222393275e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:06:22,358] Trial 55 finished with value: 72546.02259783889 and parameters: {'n_estimators': 1685, 'learning_rate': 0.041939993743612944, 'num_leaves': 62, 'max_depth': 9, 'min_child_samples': 155, 'subsample': 0.7591699633315722, 'colsample_bytree': 0.40143079402265724, 'reg_alpha': 3.545553665166968e-06, 'reg_lambda': 0.001987044188911468, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:06:53,415] Trial 56 finished with value: 72540.51525625761 and parameters: {'n_estimators': 1818, 'learning_rate': 0.05667013372288709, 'num_leaves': 246, 'max_depth': 8, 'min_child_samples': 120, 'subsample': 0.855469112146424, 'colsample_bytree': 0.42888490912596305, 'reg_alpha': 3.1156791621046944e-05, 'reg_lambda': 1.8873204467519924e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:07:29,497] Trial 57 finished with value: 72536.61278843312 and parameters: {'n_estimators': 1787, 'learning_rate': 0.05323049858073949, 'num_leaves': 105, 'max_depth': 7, 'min_child_samples': 119, 'subsample': 0.8504042597217036, 'colsample_bytree': 0.4389130675540662, 'reg_alpha': 3.123435488986844e-05, 'reg_lambda': 7.579115622019143e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:08:03,008] Trial 58 finished with value: 72568.55316416583 and parameters: {'n_estimators': 1542, 'learning_rate': 0.05679632241439115, 'num_leaves': 155, 'max_depth': 7, 'min_child_samples': 107, 'subsample': 0.8733778692847194, 'colsample_bytree': 0.53324505421034, 'reg_alpha': 0.00020080006009239664, 'reg_lambda': 4.562318938509871e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:08:36,711] Trial 59 finished with value: 72586.56639747662 and parameters: {'n_estimators': 1768, 'learning_rate': 0.06649221734781405, 'num_leaves': 174, 'max_depth': 6, 'min_child_samples': 121, 'subsample': 0.8562216044931431, 'colsample_bytree': 0.46437950577276293, 'reg_alpha': 2.9469741811182948e-05, 'reg_lambda': 7.563713886115317e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:08:55,658] Trial 60 finished with value: 72648.92534473649 and parameters: {'n_estimators': 1817, 'learning_rate': 0.13853706920641273, 'num_leaves': 214, 'max_depth': 5, 'min_child_samples': 92, 'subsample': 0.8025826485029537, 'colsample_bytree': 0.8070157286873859, 'reg_alpha': 7.52241114426164e-05, 'reg_lambda': 1.8228404576292075e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:09:34,392] Trial 61 finished with value: 72543.33949431968 and parameters: {'n_estimators': 1910, 'learning_rate': 0.04285994879751304, 'num_leaves': 101, 'max_depth': 8, 'min_child_samples': 129, 'subsample': 0.8418981499420694, 'colsample_bytree': 0.43728064360246305, 'reg_alpha': 1.9165863183663564e-05, 'reg_lambda': 1.1080686405122539e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:10:13,094] Trial 62 finished with value: 72551.84521022324 and parameters: {'n_estimators': 1712, 'learning_rate': 0.05351963506717372, 'num_leaves': 82, 'max_depth': 7, 'min_child_samples': 135, 'subsample': 0.8263638279418378, 'colsample_bytree': 0.48997988959173827, 'reg_alpha': 3.4327022512713616e-05, 'reg_lambda': 3.116145428053445e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:10:57,150] Trial 63 finished with value: 72561.09964130582 and parameters: {'n_estimators': 1814, 'learning_rate': 0.0335989035617264, 'num_leaves': 42, 'max_depth': 8, 'min_child_samples': 121, 'subsample': 0.7892073105103999, 'colsample_bytree': 0.42567888006405347, 'reg_alpha': 1.0159408644030602e-05, 'reg_lambda': 1.9735861117944458e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:11:31,770] Trial 64 finished with value: 72563.19580198839 and parameters: {'n_estimators': 1924, 'learning_rate': 0.0766703219592624, 'num_leaves': 120, 'max_depth': 9, 'min_child_samples': 144, 'subsample': 0.8857212771678981, 'colsample_bytree': 0.45015626136946285, 'reg_alpha': 6.826494562410342e-05, 'reg_lambda': 6.946562996590863e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:12:02,418] Trial 65 finished with value: 72582.4925602926 and parameters: {'n_estimators': 1857, 'learning_rate': 0.09150500739183237, 'num_leaves': 236, 'max_depth': 8, 'min_child_samples': 134, 'subsample': 0.81464593344775, 'colsample_bytree': 0.5093935023961523, 'reg_alpha': 2.484193414063089e-06, 'reg_lambda': 3.746774005710953e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:12:32,157] Trial 66 finished with value: 72544.47075730555 and parameters: {'n_estimators': 1628, 'learning_rate': 0.06207764447582344, 'num_leaves': 401, 'max_depth': 7, 'min_child_samples': 101, 'subsample': 0.8559320105323377, 'colsample_bytree': 0.40012804050743017, 'reg_alpha': 6.968786893681286e-06, 'reg_lambda': 0.024221713104726303, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:14:29,451] Trial 67 finished with value: 72538.19753033944 and parameters: {'n_estimators': 1946, 'learning_rate': 0.01027681716252686, 'num_leaves': 131, 'max_depth': 8, 'min_child_samples': 116, 'subsample': 0.8013993095330454, 'colsample_bytree': 0.47234395532759843, 'reg_alpha': 1.4983737845352258e-06, 'reg_lambda': 1.6765579951277169e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:16:01,838] Trial 68 finished with value: 72545.47327544245 and parameters: {'n_estimators': 1794, 'learning_rate': 0.014426687828282006, 'num_leaves': 147, 'max_depth': 8, 'min_child_samples': 159, 'subsample': 0.8015759274672665, 'colsample_bytree': 0.46863320280050647, 'reg_alpha': 1.0260784949765245e-06, 'reg_lambda': 1.5249617884696288e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:17:03,610] Trial 69 finished with value: 72566.12633159438 and parameters: {'n_estimators': 1992, 'learning_rate': 0.022742045806796528, 'num_leaves': 131, 'max_depth': 6, 'min_child_samples': 78, 'subsample': 0.8266180218197553, 'colsample_bytree': 0.42169073679392594, 'reg_alpha': 1.4112654497468413e-06, 'reg_lambda': 2.2172732476553472e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:18:36,561] Trial 70 finished with value: 72556.17820272187 and parameters: {'n_estimators': 1935, 'learning_rate': 0.01254030509447554, 'num_leaves': 181, 'max_depth': 8, 'min_child_samples': 110, 'subsample': 0.9101765902603268, 'colsample_bytree': 0.5566594814091639, 'reg_alpha': 5.667639584916925e-06, 'reg_lambda': 1.3616576500764502e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:19:09,436] Trial 71 finished with value: 72546.37035420936 and parameters: {'n_estimators': 1860, 'learning_rate': 0.04572653075865923, 'num_leaves': 73, 'max_depth': 9, 'min_child_samples': 118, 'subsample': 0.7709886431114741, 'colsample_bytree': 0.4425643651006345, 'reg_alpha': 3.165912539197877e-06, 'reg_lambda': 4.457493085757377e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:19:47,458] Trial 72 finished with value: 72562.781331566 and parameters: {'n_estimators': 1941, 'learning_rate': 0.055351282308179255, 'num_leaves': 99, 'max_depth': 7, 'min_child_samples': 124, 'subsample': 0.787464710358744, 'colsample_bytree': 0.4759098703620891, 'reg_alpha': 1.8076960387076185e-05, 'reg_lambda': 1.2794190093554755e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:20:30,927] Trial 73 finished with value: 72557.34761307202 and parameters: {'n_estimators': 1997, 'learning_rate': 0.03740158568635478, 'num_leaves': 109, 'max_depth': 8, 'min_child_samples': 147, 'subsample': 0.7412145637948573, 'colsample_bytree': 0.44682323345164854, 'reg_alpha': 1.8625331642250454e-06, 'reg_lambda': 2.6044878662577102e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:21:06,829] Trial 74 finished with value: 72548.67985317373 and parameters: {'n_estimators': 1696, 'learning_rate': 0.050482044096616094, 'num_leaves': 152, 'max_depth': 9, 'min_child_samples': 126, 'subsample': 0.8463001761590072, 'colsample_bytree': 0.4228827871184953, 'reg_alpha': 3.007483862773183e-06, 'reg_lambda': 7.397075776132847e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:21:57,827] Trial 75 finished with value: 72577.11209916312 and parameters: {'n_estimators': 1865, 'learning_rate': 0.028760108157783633, 'num_leaves': 129, 'max_depth': 10, 'min_child_samples': 97, 'subsample': 0.8136017145903134, 'colsample_bytree': 0.5161289778319769, 'reg_alpha': 9.041096082478862e-06, 'reg_lambda': 3.98504189366526e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:22:30,668] Trial 76 finished with value: 72585.66392916787 and parameters: {'n_estimators': 961, 'learning_rate': 0.07030800389901476, 'num_leaves': 283, 'max_depth': 8, 'min_child_samples': 131, 'subsample': 0.861693950596048, 'colsample_bytree': 0.49106792510076924, 'reg_alpha': 5.265997226475896e-06, 'reg_lambda': 2.3916936340496565e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:23:04,470] Trial 77 finished with value: 72550.4489413783 and parameters: {'n_estimators': 1944, 'learning_rate': 0.06397908018669271, 'num_leaves': 250, 'max_depth': 9, 'min_child_samples': 155, 'subsample': 0.7665057235299401, 'colsample_bytree': 0.4114437240534668, 'reg_alpha': 1.478356250043919e-05, 'reg_lambda': 1.0406328391268346e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:24:05,717] Trial 78 finished with value: 72637.55078134828 and parameters: {'n_estimators': 1145, 'learning_rate': 0.020238488815488877, 'num_leaves': 84, 'max_depth': 7, 'min_child_samples': 114, 'subsample': 0.8838304594074857, 'colsample_bytree': 0.9192063350828333, 'reg_alpha': 1.0710045916122534e-05, 'reg_lambda': 6.610103395198392e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:26:36,519] Trial 79 finished with value: 72550.07515392973 and parameters: {'n_estimators': 1384, 'learning_rate': 0.007069948285414026, 'num_leaves': 69, 'max_depth': 10, 'min_child_samples': 139, 'subsample': 0.8320959861565791, 'colsample_bytree': 0.45959479260015734, 'reg_alpha': 0.007302647681998067, 'reg_lambda': 1.4686093723302109e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:27:05,930] Trial 80 finished with value: 72572.18898035013 and parameters: {'n_estimators': 1793, 'learning_rate': 0.08416031037814789, 'num_leaves': 195, 'max_depth': 10, 'min_child_samples': 170, 'subsample': 0.8012980028377887, 'colsample_bytree': 0.43957298082244506, 'reg_alpha': 2.4544302994848698e-05, 'reg_lambda': 9.317339591052108e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:27:41,558] Trial 81 finished with value: 72542.40936048186 and parameters: {'n_estimators': 1943, 'learning_rate': 0.057012262742033804, 'num_leaves': 257, 'max_depth': 9, 'min_child_samples': 152, 'subsample': 0.7158318224975115, 'colsample_bytree': 0.41328409468846894, 'reg_alpha': 5.779657897326766e-06, 'reg_lambda': 1.5967819130906226e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:28:20,694] Trial 82 finished with value: 72534.27036876002 and parameters: {'n_estimators': 1877, 'learning_rate': 0.04620983102458977, 'num_leaves': 263, 'max_depth': 9, 'min_child_samples': 162, 'subsample': 0.689438460680702, 'colsample_bytree': 0.4115456940496098, 'reg_alpha': 5.746038619066407e-06, 'reg_lambda': 2.538393476515635e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:28:57,185] Trial 83 finished with value: 72542.65115492053 and parameters: {'n_estimators': 1860, 'learning_rate': 0.04627000012652811, 'num_leaves': 300, 'max_depth': 8, 'min_child_samples': 178, 'subsample': 0.5986078568711104, 'colsample_bytree': 0.4285190876381819, 'reg_alpha': 2.957615187562727e-06, 'reg_lambda': 3.172395990814842e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:29:48,588] Trial 84 finished with value: 72560.37490259134 and parameters: {'n_estimators': 1728, 'learning_rate': 0.03256313018920889, 'num_leaves': 271, 'max_depth': 9, 'min_child_samples': 162, 'subsample': 0.6863856199868144, 'colsample_bytree': 0.4780342382724797, 'reg_alpha': 3.8037086382113024e-06, 'reg_lambda': 5.123099927514425e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:30:32,412] Trial 85 finished with value: 72558.46297426963 and parameters: {'n_estimators': 1661, 'learning_rate': 0.03813145737272176, 'num_leaves': 209, 'max_depth': 8, 'min_child_samples': 167, 'subsample': 0.7794249018050442, 'colsample_bytree': 0.45212752423920327, 'reg_alpha': 1.7540229261713698e-06, 'reg_lambda': 2.367133719221602e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:31:07,488] Trial 86 finished with value: 72577.48679930912 and parameters: {'n_estimators': 1888, 'learning_rate': 0.07256322047252059, 'num_leaves': 324, 'max_depth': 11, 'min_child_samples': 104, 'subsample': 0.7497494877962698, 'colsample_bytree': 0.40020453554072605, 'reg_alpha': 7.981780016229364e-06, 'reg_lambda': 3.7182383005970386e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:31:41,459] Trial 87 finished with value: 72557.28178025379 and parameters: {'n_estimators': 1542, 'learning_rate': 0.05169924749183303, 'num_leaves': 109, 'max_depth': 10, 'min_child_samples': 133, 'subsample': 0.6310366214710821, 'colsample_bytree': 0.4337596306692094, 'reg_alpha': 1.4164489835244942e-05, 'reg_lambda': 1.9799601220365983e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:32:18,711] Trial 88 finished with value: 72570.83889398447 and parameters: {'n_estimators': 904, 'learning_rate': 0.059071778901786484, 'num_leaves': 229, 'max_depth': 9, 'min_child_samples': 143, 'subsample': 0.729444408274513, 'colsample_bytree': 0.4682570023723252, 'reg_alpha': 1.3876641293862232e-06, 'reg_lambda': 0.00020568277257428599, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:32:43,642] Trial 89 finished with value: 72616.37117372715 and parameters: {'n_estimators': 1812, 'learning_rate': 0.10923621616808359, 'num_leaves': 142, 'max_depth': 8, 'min_child_samples': 176, 'subsample': 0.815565701355125, 'colsample_bytree': 0.7076475903320343, 'reg_alpha': 2.3608756365426426e-06, 'reg_lambda': 5.613383850884373e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:33:24,418] Trial 90 finished with value: 72566.06401304454 and parameters: {'n_estimators': 765, 'learning_rate': 0.044782413559161835, 'num_leaves': 167, 'max_depth': 7, 'min_child_samples': 117, 'subsample': 0.8404703559089886, 'colsample_bytree': 0.5013786858209067, 'reg_alpha': 5.028221468518514e-05, 'reg_lambda': 0.0005607090135175802, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:34:03,002] Trial 91 finished with value: 72539.07086986194 and parameters: {'n_estimators': 1954, 'learning_rate': 0.05821621442660971, 'num_leaves': 264, 'max_depth': 9, 'min_child_samples': 151, 'subsample': 0.7088228669405693, 'colsample_bytree': 0.41350558364503287, 'reg_alpha': 5.592262352984047e-06, 'reg_lambda': 1.5043071880174234e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:34:34,324] Trial 92 finished with value: 72549.72437296835 and parameters: {'n_estimators': 1963, 'learning_rate': 0.06369671311424463, 'num_leaves': 244, 'max_depth': 9, 'min_child_samples': 152, 'subsample': 0.6499467153391867, 'colsample_bytree': 0.4143934439939974, 'reg_alpha': 4.651169011497338e-06, 'reg_lambda': 1.597336073575693e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:35:14,991] Trial 93 finished with value: 72541.47512974626 and parameters: {'n_estimators': 554, 'learning_rate': 0.040892638541326604, 'num_leaves': 282, 'max_depth': 9, 'min_child_samples': 138, 'subsample': 0.7178404815744807, 'colsample_bytree': 0.4335967618330524, 'reg_alpha': 2.506027424369102e-05, 'reg_lambda': 1.0088222784844017e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:35:59,463] Trial 94 finished with value: 72545.9009022223 and parameters: {'n_estimators': 1896, 'learning_rate': 0.03591281391844256, 'num_leaves': 315, 'max_depth': 9, 'min_child_samples': 158, 'subsample': 0.6954646526928221, 'colsample_bytree': 0.4302212013854246, 'reg_alpha': 0.00012774317700363298, 'reg_lambda': 1.0379134391745491e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:36:38,521] Trial 95 finished with value: 72545.64407712214 and parameters: {'n_estimators': 367, 'learning_rate': 0.04025067969630815, 'num_leaves': 277, 'max_depth': 9, 'min_child_samples': 138, 'subsample': 0.6709119544320006, 'colsample_bytree': 0.41692733606274646, 'reg_alpha': 3.6473003367980816e-05, 'reg_lambda': 2.6881454655395085e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:37:01,396] Trial 96 finished with value: 72623.49504094485 and parameters: {'n_estimators': 2000, 'learning_rate': 0.18109182878599867, 'num_leaves': 291, 'max_depth': 8, 'min_child_samples': 147, 'subsample': 0.7056179975988369, 'colsample_bytree': 0.45601920537243196, 'reg_alpha': 2.5182766321918113e-05, 'reg_lambda': 1.341107649305605e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:37:38,277] Trial 97 finished with value: 72540.9552314787 and parameters: {'n_estimators': 1776, 'learning_rate': 0.05410622289423566, 'num_leaves': 261, 'max_depth': 9, 'min_child_samples': 165, 'subsample': 0.6808936176534677, 'colsample_bytree': 0.4129273376569584, 'reg_alpha': 7.956956303483451e-06, 'reg_lambda': 3.6069747528078766e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:38:17,935] Trial 98 finished with value: 72548.3050125972 and parameters: {'n_estimators': 1767, 'learning_rate': 0.05347248606492559, 'num_leaves': 252, 'max_depth': 8, 'min_child_samples': 182, 'subsample': 0.6803482569233501, 'colsample_bytree': 0.4130716325782121, 'reg_alpha': 6.769032407380712e-06, 'reg_lambda': 4.381012274090273e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:38:51,966] Trial 99 finished with value: 72597.28438031934 and parameters: {'n_estimators': 1840, 'learning_rate': 0.059499484568241987, 'num_leaves': 220, 'max_depth': 9, 'min_child_samples': 164, 'subsample': 0.6417925087213909, 'colsample_bytree': 0.6196637709433728, 'reg_alpha': 0.0005745981934557323, 'reg_lambda': 0.8980099885858072, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:39:54,004] Trial 100 finished with value: 72612.15813804333 and parameters: {'n_estimators': 1903, 'learning_rate': 0.06714366907793672, 'num_leaves': 239, 'max_depth': 3, 'min_child_samples': 170, 'subsample': 0.6567703395824761, 'colsample_bytree': 0.444020787149921, 'reg_alpha': 3.94376598238008e-06, 'reg_lambda': 6.418282694701904e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:40:33,610] Trial 101 finished with value: 72538.99716236207 and parameters: {'n_estimators': 506, 'learning_rate': 0.04594318257096653, 'num_leaves': 300, 'max_depth': 9, 'min_child_samples': 161, 'subsample': 0.7105533518543269, 'colsample_bytree': 0.43089929284521056, 'reg_alpha': 8.956029400944555e-06, 'reg_lambda': 2.1237897727017025e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:41:09,001] Trial 102 finished with value: 72542.27006561379 and parameters: {'n_estimators': 1950, 'learning_rate': 0.046797426927253194, 'num_leaves': 303, 'max_depth': 9, 'min_child_samples': 158, 'subsample': 0.7305331388024078, 'colsample_bytree': 0.40949660358803913, 'reg_alpha': 9.827856817534765e-06, 'reg_lambda': 9.47992320317207e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:41:45,104] Trial 103 finished with value: 72544.66012055585 and parameters: {'n_estimators': 451, 'learning_rate': 0.0513190237152069, 'num_leaves': 342, 'max_depth': 8, 'min_child_samples': 162, 'subsample': 0.6869791845828683, 'colsample_bytree': 0.4270385579598819, 'reg_alpha': 2.6419115292713613e-06, 'reg_lambda': 3.4243695718175927e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:42:52,814] Trial 104 finished with value: 72550.12770114787 and parameters: {'n_estimators': 1782, 'learning_rate': 0.02467234100498747, 'num_leaves': 269, 'max_depth': 9, 'min_child_samples': 150, 'subsample': 0.8231253571581698, 'colsample_bytree': 0.46193831822946557, 'reg_alpha': 1.639429149019639e-05, 'reg_lambda': 2.223085500765439e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:43:18,362] Trial 105 finished with value: 72631.69397487566 and parameters: {'n_estimators': 1878, 'learning_rate': 0.15375294177472817, 'num_leaves': 264, 'max_depth': 10, 'min_child_samples': 183, 'subsample': 0.7072436128236842, 'colsample_bytree': 0.4007087652980335, 'reg_alpha': 0.002097703346426115, 'reg_lambda': 1.7893136419513525e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:43:51,611] Trial 106 finished with value: 72550.13816459959 and parameters: {'n_estimators': 316, 'learning_rate': 0.05885193351449656, 'num_leaves': 300, 'max_depth': 9, 'min_child_samples': 154, 'subsample': 0.6789635890190314, 'colsample_bytree': 0.44779497994298656, 'reg_alpha': 5.707913760331108e-06, 'reg_lambda': 2.7023309479782774e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:44:22,806] Trial 107 finished with value: 72556.29426090069 and parameters: {'n_estimators': 1830, 'learning_rate': 0.07335821541292668, 'num_leaves': 358, 'max_depth': 8, 'min_child_samples': 173, 'subsample': 0.7419221071393491, 'colsample_bytree': 0.4243552832349525, 'reg_alpha': 7.672449954094881e-06, 'reg_lambda': 1.2980535902514105e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:45:03,523] Trial 108 finished with value: 72578.57374020964 and parameters: {'n_estimators': 1732, 'learning_rate': 0.05502137965152279, 'num_leaves': 332, 'max_depth': 7, 'min_child_samples': 159, 'subsample': 0.8591946374209795, 'colsample_bytree': 0.47948835890286134, 'reg_alpha': 1.300379894429357e-06, 'reg_lambda': 4.172728862107867e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:45:24,892] Trial 109 finished with value: 72628.4951403738 and parameters: {'n_estimators': 1921, 'learning_rate': 0.19096224686081836, 'num_leaves': 233, 'max_depth': 9, 'min_child_samples': 166, 'subsample': 0.7911830155737273, 'colsample_bytree': 0.43907351390002536, 'reg_alpha': 1.944623286419716e-06, 'reg_lambda': 0.25263973358758113, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:45:50,555] Trial 110 finished with value: 72540.67216584632 and parameters: {'n_estimators': 202, 'learning_rate': 0.04844352172285731, 'num_leaves': 128, 'max_depth': 8, 'min_child_samples': 146, 'subsample': 0.8482584549434198, 'colsample_bytree': 0.41400188193402665, 'reg_alpha': 4.428524560961273e-06, 'reg_lambda': 7.435420354818417e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:46:25,077] Trial 111 finished with value: 72547.34969208858 and parameters: {'n_estimators': 304, 'learning_rate': 0.04945296474097031, 'num_leaves': 114, 'max_depth': 8, 'min_child_samples': 146, 'subsample': 0.8466978032168143, 'colsample_bytree': 0.4124781035914967, 'reg_alpha': 4.837382937359166e-06, 'reg_lambda': 7.480005190175026e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:46:53,166] Trial 112 finished with value: 72543.64194358524 and parameters: {'n_estimators': 221, 'learning_rate': 0.04488016287891379, 'num_leaves': 131, 'max_depth': 8, 'min_child_samples': 123, 'subsample': 0.834371458239025, 'colsample_bytree': 0.45565119134371346, 'reg_alpha': 3.707434535621449e-06, 'reg_lambda': 1.649323861942066e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:47:22,381] Trial 113 finished with value: 72547.96346329618 and parameters: {'n_estimators': 468, 'learning_rate': 0.06665582237719898, 'num_leaves': 124, 'max_depth': 7, 'min_child_samples': 128, 'subsample': 0.8776313589087589, 'colsample_bytree': 0.4332199299226345, 'reg_alpha': 1.3222026063417949e-05, 'reg_lambda': 5.205841111157437e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:47:52,372] Trial 114 finished with value: 72547.79315515108 and parameters: {'n_estimators': 1949, 'learning_rate': 0.0617647706360236, 'num_leaves': 104, 'max_depth': 9, 'min_child_samples': 151, 'subsample': 0.867134359915264, 'colsample_bytree': 0.4220130039041919, 'reg_alpha': 2.5170950196373472e-06, 'reg_lambda': 3.5714552619859987e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:48:24,207] Trial 115 finished with value: 72555.62131420433 and parameters: {'n_estimators': 254, 'learning_rate': 0.034838816599035205, 'num_leaves': 158, 'max_depth': 8, 'min_child_samples': 143, 'subsample': 0.8217866345506819, 'colsample_bytree': 0.41157495419393886, 'reg_alpha': 1.046591361958462e-06, 'reg_lambda': 9.927860140268753e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:48:55,621] Trial 116 finished with value: 72556.01677219495 and parameters: {'n_estimators': 571, 'learning_rate': 0.07963563741866042, 'num_leaves': 137, 'max_depth': 9, 'min_child_samples': 168, 'subsample': 0.6705076119387123, 'colsample_bytree': 0.44562116256496737, 'reg_alpha': 0.1611362315093803, 'reg_lambda': 2.1882833884693305e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:49:37,660] Trial 117 finished with value: 72641.33831287992 and parameters: {'n_estimators': 1966, 'learning_rate': 0.028084494160136746, 'num_leaves': 93, 'max_depth': 10, 'min_child_samples': 20, 'subsample': 0.8073603026464553, 'colsample_bytree': 0.46861232513480233, 'reg_alpha': 8.350787649699452e-06, 'reg_lambda': 2.2550768901742728e-05, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:50:17,398] Trial 118 finished with value: 72551.41402159723 and parameters: {'n_estimators': 1860, 'learning_rate': 0.04158475999501112, 'num_leaves': 147, 'max_depth': 8, 'min_child_samples': 161, 'subsample': 0.7613189486822035, 'colsample_bytree': 0.4052043356521239, 'reg_alpha': 0.01813349483299412, 'reg_lambda': 1.6730338590112937e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:50:51,821] Trial 119 finished with value: 72607.3019638961 and parameters: {'n_estimators': 1913, 'learning_rate': 0.05468602738238465, 'num_leaves': 255, 'max_depth': 7, 'min_child_samples': 56, 'subsample': 0.8521617278919625, 'colsample_bytree': 0.4857639083889055, 'reg_alpha': 1.667721159836353e-06, 'reg_lambda': 0.009410677131027086, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:52:33,877] Trial 120 finished with value: 72578.46592607787 and parameters: {'n_estimators': 625, 'learning_rate': 0.009384253426538937, 'num_leaves': 287, 'max_depth': 9, 'min_child_samples': 113, 'subsample': 0.7975413719808934, 'colsample_bytree': 0.667004934285456, 'reg_alpha': 5.972381221875253e-06, 'reg_lambda': 2.84904297774079e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:53:16,234] Trial 121 finished with value: 72545.13064838664 and parameters: {'n_estimators': 1999, 'learning_rate': 0.03940493799157707, 'num_leaves': 175, 'max_depth': 9, 'min_child_samples': 141, 'subsample': 0.7145024467047215, 'colsample_bytree': 0.43389880369364037, 'reg_alpha': 1.108753009347952e-05, 'reg_lambda': 0.005685087407576711, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:53:55,301] Trial 122 finished with value: 72540.469282064 and parameters: {'n_estimators': 377, 'learning_rate': 0.0481767664748882, 'num_leaves': 280, 'max_depth': 9, 'min_child_samples': 138, 'subsample': 0.7165447867934042, 'colsample_bytree': 0.42990971116116805, 'reg_alpha': 2.116045691640308e-05, 'reg_lambda': 1.0319143339422674e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:54:31,638] Trial 123 finished with value: 72618.39230374737 and parameters: {'n_estimators': 400, 'learning_rate': 0.048336458340894575, 'num_leaves': 275, 'max_depth': 9, 'min_child_samples': 154, 'subsample': 0.6944435320638157, 'colsample_bytree': 0.8378460426017811, 'reg_alpha': 2.0786600690361334e-05, 'reg_lambda': 1.6397792046710582e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:55:01,696] Trial 124 finished with value: 72530.4563004921 and parameters: {'n_estimators': 260, 'learning_rate': 0.05167243856527939, 'num_leaves': 309, 'max_depth': 8, 'min_child_samples': 119, 'subsample': 0.8306064265413764, 'colsample_bytree': 0.4223496041274077, 'reg_alpha': 3.2633627219206064e-06, 'reg_lambda': 1.354186098389875e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:55:33,198] Trial 125 finished with value: 72543.89648529467 and parameters: {'n_estimators': 304, 'learning_rate': 0.04480344796338115, 'num_leaves': 307, 'max_depth': 8, 'min_child_samples': 117, 'subsample': 0.8378739636750686, 'colsample_bytree': 0.4006876632745449, 'reg_alpha': 3.349950196310773e-06, 'reg_lambda': 1.2888015296161434e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# [I 2025-09-12 09:56:16,415] Trial 126 finished with value: 76822.7776094181 and parameters: {'n_estimators': 261, 'learning_rate': 0.001090631738477463, 'num_leaves': 261, 'max_depth': 8, 'min_child_samples': 128, 'subsample': 0.7224507420933634, 'colsample_bytree': 0.45578168962942883, 'reg_alpha': 4.395520837514431e-06, 'reg_lambda': 2.030148718036427e-06, 'boosting_type': 'gbdt'}. Best is trial 25 with value: 72527.33246460892.
# Best parameters for LightGBM: {'n_estimators': 1995, 'learning_rate': 0.05101421798433064, 'num_leaves': 98, 'max_depth': 9, 'min_child_samples': 155, 'subsample': 0.795214556350197, 'colsample_bytree': 0.437798275994333, 'reg_alpha': 7.733789387891466e-06, 'reg_lambda': 1.2064000395683555e-06, 'boosting_type': 'gbdt'}
# Best RMSE for LightGBM: 72527.33246460892

# %%
n_splits = 10
fold = KFold(n_splits=n_splits, shuffle=True, random_state=42)

oof_preds = np.zeros(len(X_lgbm))          # store OOF predictions for whole train set
y_pred_folds = []                     # store per-fold test predictions
rmse = []

i = 1
for train_index, val_index in fold.split(X_lgbm, y):
    print(f"Fold {i}/{n_splits}:")

    X_tr, X_val = X_lgbm.iloc[train_index], X_lgbm.iloc[val_index]
    y_tr, y_val = y.iloc[train_index], y.iloc[val_index]

    m = LGBMRegressor(**best_lgb_params)

    # fit with early stopping rounds
    m.fit(
        X_tr, y_tr,
        eval_set=[(X_val, y_val)],
        eval_metric='rmse',
        callbacks=[lgb.early_stopping(stopping_rounds=100)]
    )

    # predict validation using best_iteration_
    preds = m.predict(X_val, num_iteration=m.best_iteration_)
    oof_preds[val_index] = preds            # assign to OOF array

    r_error = root_mean_squared_error(y_val, preds)
    rmse.append(r_error)

    print(f"Fold {i} — RMSE: {r_error:.6f}  R2: {r2_score(y_val, preds):.6f}")

    # predict test set using best_iteration_ and store prediction
    pr = m.predict(test_data_lgbm, num_iteration=m.best_iteration_)
    y_pred_folds.append(pr)

    i += 1

# OOF Estimate
overall_oof_rmse = root_mean_squared_error(y, oof_preds)
print(f"\nOOF RMSE: {overall_oof_rmse:.6f}")
print(f"Per-fold RMSE mean ± std: {np.mean(rmse):.6f} ± {np.std(rmse):.6f}")

# aggregate test predictions across folds (mean)
final_test_pred_mean_lgbm = np.mean(y_pred_folds, axis=0)
# median aggregation
# final_test_pred_median_lgbm = np.median(y_pred_folds, axis=0)
# Out:
# Fold 1/10:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [233]	valid_0's rmse: 69049.9	valid_0's l2: 4.76788e+09
# Fold 1 — RMSE: 69049.859968  R2: 0.167384
# Fold 2/10:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [125]	valid_0's rmse: 66514.1	valid_0's l2: 4.42412e+09
# Fold 2 — RMSE: 66514.095519  R2: 0.180050
# Fold 3/10:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [120]	valid_0's rmse: 62379.8	valid_0's l2: 3.89123e+09
# Fold 3 — RMSE: 62379.754863  R2: 0.175577
# Fold 4/10:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [199]	valid_0's rmse: 74181.7	valid_0's l2: 5.50292e+09
# Fold 4 — RMSE: 74181.677495  R2: 0.152250
# Fold 5/10:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [135]	valid_0's rmse: 84989.6	valid_0's l2: 7.22323e+09
# Fold 5 — RMSE: 84989.604896  R2: 0.108808
# Fold 6/10:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [107]	valid_0's rmse: 60711.5	valid_0's l2: 3.68589e+09
# Fold 6 — RMSE: 60711.521625  R2: 0.193960
# Fold 7/10:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [230]	valid_0's rmse: 74445.5	valid_0's l2: 5.54213e+09
# Fold 7 — RMSE: 74445.453036  R2: 0.150572
# Fold 8/10:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [158]	valid_0's rmse: 78204.7	valid_0's l2: 6.11598e+09
# Fold 8 — RMSE: 78204.707301  R2: 0.135186
# Fold 9/10:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [178]	valid_0's rmse: 71077.8	valid_0's l2: 5.05205e+09
# Fold 9 — RMSE: 71077.791038  R2: 0.160331
# Fold 10/10:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [156]	valid_0's rmse: 80853.7	valid_0's l2: 6.53733e+09
# Fold 10 — RMSE: 80853.747803  R2: 0.128314
#
# OOF RMSE: 72624.116022
# Per-fold RMSE mean ± std: 72240.821354 ± 7452.549163

# %%
oof_preds
# Out:
# array([ 9292.37299504, 11350.55065667, 12311.68556948, ...,
#        83042.0037103 , 68272.08410518, 31629.79230968])

# %%
# !pip install catBoost

from catboost import CatBoostRegressor, Pool
# Out:
# Collecting catBoost
#   Downloading catboost-1.2.8-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catBoost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catBoost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catBoost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catBoost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catBoost) (1.16.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catBoost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catBoost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catBoost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catBoost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catBoost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catBoost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catBoost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catBoost) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catBoost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catBoost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catBoost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catBoost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catBoost) (8.5.0)
# Downloading catboost-1.2.8-cp312-cp312-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.0 MB/s eta 0:00:00
# Installing collected packages: catBoost
# Successfully installed catBoost-1.2.8

# %%
import optuna

# Define Optuna objective functions for CatBoost
def objective_catboost(trial):
    catboost_params = {
        "iterations": trial.suggest_int("iterations", 500, 5000), # Tunable
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.2, log=True), # Tunable
        "depth": trial.suggest_int("depth", 4, 10), # Tunable
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-6, 10.0, log=True), # Tunable
        "loss_function": "RMSE",
        "eval_metric": "RMSE",
        "random_state": 42,
        "verbose": 0,
        "early_stopping_rounds": 200, # Tunable
        "cat_features": cat_cols # Use non-encoded categorical features
    }

    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    rmse_scores = []

    for fold, (tr_idx, val_idx) in enumerate(cv.split(X_cat, y)):
        X_tr, X_val = X_cat.iloc[tr_idx], X_cat.iloc[val_idx]
        y_tr, y_val = y.iloc[tr_idx], y.iloc[val_idx]

        train_pool = Pool(data=X_tr, label=y_tr, cat_features=cat_cols)
        val_pool = Pool(data=X_val, label=y_val, cat_features=cat_cols)

        model = CatBoostRegressor(**catboost_params)
        model.fit(train_pool, eval_set=val_pool, early_stopping_rounds=catboost_params["early_stopping_rounds"], verbose=False)

        preds = model.predict(val_pool)
        rmse = root_mean_squared_error(y_val, preds)
        rmse_scores.append(rmse)

    return np.mean(rmse_scores)


# Run Optuna studies for CatBoost
print("Running Optuna study for CatBoost...")
pruner = optuna.pruners.SuccessiveHalvingPruner()
study_catboost = optuna.create_study(direction="minimize", pruner=pruner)
study_catboost.optimize(objective_catboost, n_trials=150, timeout=60*90)

print("\nBest parameters for CatBoost:", study_catboost.best_params)
print("Best RMSE for CatBoost:", study_catboost.best_value)
best_catboost_params = study_catboost.best_params
# Out:
# [I 2025-09-12 09:58:00,975] A new study created in memory with name: no-name-470487bd-e81b-4981-ace7-6cb6cc8ec31e
# Running Optuna study for CatBoost...
# [I 2025-09-12 10:16:55,647] Trial 0 finished with value: 72968.22192255367 and parameters: {'iterations': 1891, 'learning_rate': 0.1009904690143163, 'depth': 10, 'l2_leaf_reg': 0.00019131566317391068}. Best is trial 0 with value: 72968.22192255367.
# [I 2025-09-12 11:11:31,019] Trial 1 finished with value: 73058.80580065653 and parameters: {'iterations': 888, 'learning_rate': 0.0029728415475214587, 'depth': 10, 'l2_leaf_reg': 2.1918527074988196e-06}. Best is trial 0 with value: 72968.22192255367.
# [I 2025-09-12 11:52:47,702] Trial 2 finished with value: 72817.30406403168 and parameters: {'iterations': 2790, 'learning_rate': 0.012560903908017925, 'depth': 5, 'l2_leaf_reg': 0.0010769890121875914}. Best is trial 2 with value: 72817.30406403168.
# Best parameters for CatBoost: {'iterations': 2790, 'learning_rate': 0.012560903908017925, 'depth': 5, 'l2_leaf_reg': 0.0010769890121875914}
# Best RMSE for CatBoost: 72817.30406403168

# %%
n_splits = 10
fold = KFold(n_splits=n_splits, shuffle=True, random_state=42)

oof_preds_catboost = np.zeros(len(X_cat))          # store OOF predictions for whole train set
y_pred_folds_catboost = []                     # store per-fold test predictions
rmse_catboost = []

# Identify categorical features for CatBoost
cat_features_indices = [X_cat.columns.get_loc(col) for col in cat_cols]

i = 1
for train_index, val_index in fold.split(X_cat, y):
    print(f"Fold {i}/{n_splits}:")

    X_tr, X_val = X_cat.iloc[train_index], X_cat.iloc[val_index]
    y_tr, y_val = y.iloc[train_index], y.iloc[val_index]

    # Create CatBoost Pool objects
    train_pool = Pool(data=X_tr, label=y_tr, cat_features=cat_features_indices)
    val_pool = Pool(data=X_val, label=y_val, cat_features=cat_features_indices)
    test_pool = Pool(data=test_data_cat, cat_features=cat_features_indices)


    m_catboost = CatBoostRegressor(**best_catboost_params)

    # fit with early stopping rounds
    m_catboost.fit(
        train_pool,
        eval_set=val_pool,
        early_stopping_rounds=100,
        verbose=False
    )

    # predict validation using best_iteration_
    preds_catboost = m_catboost.predict(val_pool)
    oof_preds_catboost[val_index] = preds_catboost

    r_error_catboost = root_mean_squared_error(y_val, preds_catboost)
    rmse_catboost.append(r_error_catboost)

    print(f"Fold {i} — RMSE: {r_error_catboost:.6f}  R2: {r2_score(y_val, preds_catboost):.6f}")

    # predict test set using best_iteration_ and store predictions
    pr_catboost = m_catboost.predict(test_pool)
    y_pred_folds_catboost.append(pr_catboost)

    i += 1

# OOF Estimate
overall_oof_rmse_catboost = root_mean_squared_error(y, oof_preds_catboost)
print(f"\nOOF RMSE (CatBoost): {overall_oof_rmse_catboost:.6f}")
print(f"Per-fold RMSE mean ± std (CatBoost): {np.mean(rmse_catboost):.6f} ± {np.std(rmse_catboost):.6f}")

# aggregate test predictions across folds (mean)
final_test_pred_mean_catboost = np.mean(y_pred_folds_catboost, axis=0)
# # median aggregation
# final_test_pred_median_catboost = np.median(y_pred_folds_catboost, axis=0)
# Out:
# Fold 1/10:
# Fold 1 — RMSE: 69156.714498  R2: 0.164806
# Fold 2/10:
# Fold 2 — RMSE: 66903.684105  R2: 0.170416
# Fold 3/10:
# Fold 3 — RMSE: 62568.945070  R2: 0.170568
# Fold 4/10:
# Fold 4 — RMSE: 74514.685207  R2: 0.144621
# Fold 5/10:
# Fold 5 — RMSE: 85173.568318  R2: 0.104946
# Fold 6/10:
# Fold 6 — RMSE: 60728.935246  R2: 0.193498
# Fold 7/10:
# Fold 7 — RMSE: 74659.438280  R2: 0.145681
# Fold 8/10:
# Fold 8 — RMSE: 78559.904242  R2: 0.127312
# Fold 9/10:
# Fold 9 — RMSE: 71699.400261  R2: 0.145580
# Fold 10/10:
# Fold 10 — RMSE: 81022.469507  R2: 0.124672
#
# OOF RMSE (CatBoost): 72883.190070
# Per-fold RMSE mean ± std (CatBoost): 72498.774473 ± 7476.747033

# %%
# Ensemble the predictions by taking the average
final_ensembled_predictions = (final_test_pred_mean_lgbm + final_test_pred_mean_catboost) / 2

# Create a submission DataFrame
submission_df = pd.DataFrame({'id': test_data_n['id'], 'price': final_ensembled_predictions})

# Display the first few rows of the submission file
display(submission_df.head())
# Out:
#        id         price
# 0  188533  17473.559805
# 1  188534  79126.343638
# 2  188535  53299.491181
# 3  188536  24993.471052
# 4  188537  30990.401407

# %%
submission_df.to_csv("optuna2_oof_lgbm+cat_sub.csv", index=False)
